# %% [markdown]
# # Face Recognition of 5 Sports Celebrity
# This Model Recognise 5 sports celebrity which are Ellyse Perry, Virat Kohli, Smriti Mandhana, MS Dhoni, Lionel Messi

# %% [markdown]
# ## Load packages

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('./test_images/smriti1.jpg')
img.shape
# Out:
# (194, 259, 3)

# %%
plt.imshow(img)

# %% [markdown]
# ## Convert Image into gray scale image

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (194, 259)

# %%
gray
# Out:
# array([[ 58,  57,  58, ...,  26,  52, 109],
#        [ 58,  58,  57, ...,  24,  50, 107],
#        [ 59,  58,  57, ...,  20,  46, 103],
#        ...,
#        [120, 119, 117, ..., 153, 150, 145],
#        [122, 121, 119, ..., 149, 156, 162],
#        [122, 121, 119, ..., 149, 155, 162]], dtype=uint8)

# %%
plt.imshow(gray, cmap='gray')

# %% [markdown]
# ## Add Haarcascade for face and eye

# %%
face_cascade = cv2.CascadeClassifier('./opencv/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[ 98,  40, 105, 105]], dtype=int32)

# %%
x, y, w, h = faces[0]
x, y, w, h
# Out:
# (98, 40, 105, 105)

# %% [markdown]
# ## Detecting face using opencv rectangle

# %%
face_img = cv2.rectangle(img, (x, y), (x+w, y+h), (255, 0, 0), 2)
plt.imshow(face_img)

# %% [markdown]
# ## Detecting Eyes using opencv

# %%
cv2.destroyAllWindows()
for (x, y, w, h) in faces:
    face_img = cv2.rectangle(img, (x, y), (x+w, y+h), (255, 0, 0), 2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex, ey, ew, eh) in eyes:
        cv2.rectangle(roi_color, (ex, ey), (ex+ew, ey+eh), (0,255,0), 2)
        
plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %%
plt.imshow(roi_color, cmap='gray')

# %% [markdown]
# ## Crop all images if images have 2 eyes

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x, y, w, h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
original_image = cv2.imread("./test_images/ellyse_perry1.jpg")
plt.imshow(original_image)

# %%
cropped_image = get_cropped_image_if_2_eyes('./test_images/ellyse_perry1.jpg')
plt.imshow(cropped_image)

# %%
cropped_image_no_2_eyes = get_cropped_image_if_2_eyes('./test_images/ellyse_perry3.jpg')
cropped_image_no_2_eyes
# Out:
# array([[[ 18,   3,  47],
#         [ 18,   3,  47],
#         [ 18,   3,  47],
#         ...,
#         [ 20,  31,  61],
#         [ 22,  33,  63],
#         [ 26,  36,  66]],
#
#        [[ 18,   3,  47],
#         [ 18,   3,  47],
#         [ 18,   3,  47],
#         ...,
#         [ 20,  31,  61],
#         [ 21,  32,  62],
#         [ 25,  35,  65]],
#
#        [[ 18,   3,  47],
#         [ 18,   3,  47],
#         [ 18,   3,  47],
#         ...,
#         [ 20,  31,  61],
#         [ 21,  32,  62],
#         [ 23,  33,  63]],
#
#        ...,
#
#        [[110, 153, 192],
#         [121, 164, 203],
#         [121, 164, 203],
#         ...,
#         [ 91, 132, 165],
#         [ 95, 132, 166],
#         [120, 155, 188]],
#
#        [[106, 147, 186],
#         [122, 163, 202],
#         [122, 165, 204],
#         ...,
#         [ 97, 135, 169],
#         [ 95, 132, 166],
#         [126, 161, 195]],
#
#        [[105, 146, 185],
#         [119, 160, 199],
#         [122, 163, 202],
#         ...,
#         [ 98, 137, 169],
#         [102, 139, 173],
#         [127, 159, 194]]], dtype=uint8)

# %%
path_to_data = "./datasets/"
path_to_cr_data = "./datasets/cropped/"

# %% [markdown]
# ## Make directory to save cropped Image

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./datasets/cropped',
#  './datasets/ellyse_perry',
#  './datasets/lionel_messi',
#  './datasets/ms_dhoni',
#  './datasets/smriti_mandhana',
#  './datasets/virat_kohli']

# %%
import shutil
if os.path.exists(path_to_cr_data):
    shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}

for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    print(celebrity_name)
    
    celebrity_file_names_dict[celebrity_name] = []
    
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ", cropped_folder)
                
            cropped_file_name = celebrity_name + str(count) + '.png'
            cropped_file_path = cropped_folder + '/' + cropped_file_name
            
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# cropped
# ellyse_perry
# Generating cropped images in folder:  ./datasets/cropped/ellyse_perry
# lionel_messi
# Generating cropped images in folder:  ./datasets/cropped/lionel_messi
# ms_dhoni
# Generating cropped images in folder:  ./datasets/cropped/ms_dhoni
# smriti_mandhana
# Generating cropped images in folder:  ./datasets/cropped/smriti_mandhana
# virat_kohli
# Generating cropped images in folder:  ./datasets/cropped/virat_kohli

# %%
import pywt

def w2d(img, mode='haar', level=1):
    imArray = img
    
    #Datatype conversion
    #convert to grayscale
    imArray = cv2.cvtColor(imArray, cv2.COLOR_RGB2GRAY)
    
    #convert to float
    imArray = np.float32(imArray)
    imArray /= 255
    
    #compute cofficient
    coeffs = pywt.wavedec2(imArray, mode, level=level)
    
    #process coefficient
    coeffs_H = list(coeffs)
    coeffs_H[0] *= 0
    
    #reconstruction
    imArray_H = pywt.waverec2(coeffs_H, mode)
    imArray_H *= 255
    imArray_H = np.uint8(imArray_H)
    
    return imArray_H

# %%
im_har = w2d(cropped_image, 'db1', 5)
plt.imshow(im_har, cmap='gray')

# %% [markdown]
# ## Make Dictionary of clebrity name and image file name

# %%
celebrity_file_names_dict = {}
for img_dir in cropped_image_dirs:
    celebrity_name = img_dir.split('/')[-1]
    file_list = []
    for entry in os.scandir(img_dir):
        file_list.append(entry.path)
    celebrity_file_names_dict[celebrity_name] = file_list
celebrity_file_names_dict
# Out:
# {'ellyse_perry': ['./datasets/cropped/ellyse_perry\\ellyse_perry10.png',
#   './datasets/cropped/ellyse_perry\\ellyse_perry11.png',
#   './datasets/cropped/ellyse_perry\\ellyse_perry12.png',
#   './datasets/cropped/ellyse_perry\\ellyse_perry13.png',
#   './datasets/cropped/ellyse_perry\\ellyse_perry14.png',
#   './datasets/cropped/ellyse_perry\\ellyse_perry15.png',
#   './datasets/cropped/ellyse_perry\\ellyse_perry16.png',
#   './datasets/cropped/ellyse_perry\\ellyse_perry17.png',
#   './datasets/cropped/ellyse_perry\\ellyse_perry18.png',
#   './datasets/cropped/ellyse_perry\\ellyse_perry19.png',
#   './datasets/cropped/ellyse_perry\\ellyse_perry2.png',
#   './datasets/cropped/ellyse_perry\\ellyse_perry20.png',
#   './datasets/cropped/ellyse_perry\\ellyse_perry23.png',
#   './datasets/cropped/ellyse_perry\\ellyse_perry24.png',
#   './datasets/cropped/ellyse_perry\\ellyse_perry27.png',
#   './datasets/cropped/ellyse_perry\\ellyse_perry28.png',
#   './datasets/cropped/ellyse_perry\\ellyse_perry3.png',
#   './datasets/cropped/ellyse_perry\\ellyse_perry30.png',
#   './datasets/cropped/ellyse_perry\\ellyse_perry31.png',
#   './datasets/cropped/ellyse_perry\\ellyse_perry33.png',
#   './datasets/cropped/ellyse_perry\\ellyse_perry34.png',
#   './datasets/cropped/ellyse_perry\\ellyse_perry36.png',
#   './datasets/cropped/ellyse_perry\\ellyse_perry4.png',
#   './datasets/cropped/ellyse_perry\\ellyse_perry40.png',
#   './datasets/cropped/ellyse_perry\\ellyse_perry41.png',
#   './datasets/cropped/ellyse_perry\\ellyse_perry42.png',
#   './datasets/cropped/ellyse_perry\\ellyse_perry43.png',
#   './datasets/cropped/ellyse_perry\\ellyse_perry44.png',
#   './datasets/cropped/ellyse_perry\\ellyse_perry45.png',
#   './datasets/cropped/ellyse_perry\\ellyse_perry48.png',
#   './datasets/cropped/ellyse_perry\\ellyse_perry49.png',
#   './datasets/cropped/ellyse_perry\\ellyse_perry5.png',
#   './datasets/cropped/ellyse_perry\\ellyse_perry50.png',
#   './datasets/cropped/ellyse_perry\\ellyse_perry51.png',
#   './datasets/cropped/ellyse_perry\\ellyse_perry52.png',
#   './datasets/cropped/ellyse_perry\\ellyse_perry53.png',
#   './datasets/cropped/ellyse_perry\\ellyse_perry54.png',
#   './datasets/cropped/ellyse_perry\\ellyse_perry55.png',
#   './datasets/cropped/ellyse_perry\\ellyse_perry56.png',
#   './datasets/cropped/ellyse_perry\\ellyse_perry6.png',
#   './datasets/cropped/ellyse_perry\\ellyse_perry7.png',
#   './datasets/cropped/ellyse_perry\\ellyse_perry8.png',
#   './datasets/cropped/ellyse_perry\\ellyse_perry9.png'],
#  'lionel_messi': ['./datasets/cropped/lionel_messi\\lionel_messi1.png',
#   './datasets/cropped/lionel_messi\\lionel_messi10.png',
#   './datasets/cropped/lionel_messi\\lionel_messi11.png',
#   './datasets/cropped/lionel_messi\\lionel_messi14.png',
#   './datasets/cropped/lionel_messi\\lionel_messi15.png',
#   './datasets/cropped/lionel_messi\\lionel_messi17.png',
#   './datasets/cropped/lionel_messi\\lionel_messi18.png',
#   './datasets/cropped/lionel_messi\\lionel_messi19.png',
#   './datasets/cropped/lionel_messi\\lionel_messi2.png',
#   './datasets/cropped/lionel_messi\\lionel_messi21.png',
#   './datasets/cropped/lionel_messi\\lionel_messi22.png',
#   './datasets/cropped/lionel_messi\\lionel_messi23.png',
#   './datasets/cropped/lionel_messi\\lionel_messi24.png',
#   './datasets/cropped/lionel_messi\\lionel_messi25.png',
#   './datasets/cropped/lionel_messi\\lionel_messi26.png',
#   './datasets/cropped/lionel_messi\\lionel_messi27.png',
#   './datasets/cropped/lionel_messi\\lionel_messi28.png',
#   './datasets/cropped/lionel_messi\\lionel_messi3.png',
#   './datasets/cropped/lionel_messi\\lionel_messi30.png',
#   './datasets/cropped/lionel_messi\\lionel_messi31.png',
#   './datasets/cropped/lionel_messi\\lionel_messi33.png',
#   './datasets/cropped/lionel_messi\\lionel_messi34.png',
#   './datasets/cropped/lionel_messi\\lionel_messi35.png',
#   './datasets/cropped/lionel_messi\\lionel_messi36.png',
#   './datasets/cropped/lionel_messi\\lionel_messi37.png',
#   './datasets/cropped/lionel_messi\\lionel_messi38.png',
#   './datasets/cropped/lionel_messi\\lionel_messi39.png',
#   './datasets/cropped/lionel_messi\\lionel_messi4.png',
#   './datasets/cropped/lionel_messi\\lionel_messi40.png',
#   './datasets/cropped/lionel_messi\\lionel_messi42.png',
#   './datasets/cropped/lionel_messi\\lionel_messi45.png',
#   './datasets/cropped/lionel_messi\\lionel_messi46.png',
#   './datasets/cropped/lionel_messi\\lionel_messi48.png',
#   './datasets/cropped/lionel_messi\\lionel_messi55.png',
#   './datasets/cropped/lionel_messi\\lionel_messi57.png',
#   './datasets/cropped/lionel_messi\\lionel_messi60.png',
#   './datasets/cropped/lionel_messi\\lionel_messi62.png',
#   './datasets/cropped/lionel_messi\\lionel_messi66.png',
#   './datasets/cropped/lionel_messi\\lionel_messi7.png',
#   './datasets/cropped/lionel_messi\\lionel_messi71.png',
#   './datasets/cropped/lionel_messi\\lionel_messi73.png',
#   './datasets/cropped/lionel_messi\\lionel_messi8.png',
#   './datasets/cropped/lionel_messi\\lionel_messi9.png'],
#  'ms_dhoni': ['./datasets/cropped/ms_dhoni\\ms_dhoni1.png',
#   './datasets/cropped/ms_dhoni\\ms_dhoni10.png',
#   './datasets/cropped/ms_dhoni\\ms_dhoni11.png',
#   './datasets/cropped/ms_dhoni\\ms_dhoni12.png',
#   './datasets/cropped/ms_dhoni\\ms_dhoni13.png',
#   './datasets/cropped/ms_dhoni\\ms_dhoni14.png',
#   './datasets/cropped/ms_dhoni\\ms_dhoni15.png',
#   './datasets/cropped/ms_dhoni\\ms_dhoni16.png',
#   './datasets/cropped/ms_dhoni\\ms_dhoni17.png',
#   './datasets/cropped/ms_dhoni\\ms_dhoni19.png',
#   './datasets/cropped/ms_dhoni\\ms_dhoni2.png',
#   './datasets/cropped/ms_dhoni\\ms_dhoni21.png',
#   './datasets/cropped/ms_dhoni\\ms_dhoni22.png',
#   './datasets/cropped/ms_dhoni\\ms_dhoni23.png',
#   './datasets/cropped/ms_dhoni\\ms_dhoni24.png',
#   './datasets/cropped/ms_dhoni\\ms_dhoni26.png',
#   './datasets/cropped/ms_dhoni\\ms_dhoni27.png',
#   './datasets/cropped/ms_dhoni\\ms_dhoni28.png',
#   './datasets/cropped/ms_dhoni\\ms_dhoni3.png',
#   './datasets/cropped/ms_dhoni\\ms_dhoni30.png',
#   './datasets/cropped/ms_dhoni\\ms_dhoni31.png',
#   './datasets/cropped/ms_dhoni\\ms_dhoni32.png',
#   './datasets/cropped/ms_dhoni\\ms_dhoni33.png',
#   './datasets/cropped/ms_dhoni\\ms_dhoni35.png',
#   './datasets/cropped/ms_dhoni\\ms_dhoni36.png',
#   './datasets/cropped/ms_dhoni\\ms_dhoni37.png',
#   './datasets/cropped/ms_dhoni\\ms_dhoni4.png',
#   './datasets/cropped/ms_dhoni\\ms_dhoni42.png',
#   './datasets/cropped/ms_dhoni\\ms_dhoni43.png',
#   './datasets/cropped/ms_dhoni\\ms_dhoni46.png',
#   './datasets/cropped/ms_dhoni\\ms_dhoni47.png',
#   './datasets/cropped/ms_dhoni\\ms_dhoni5.png',
#   './datasets/cropped/ms_dhoni\\ms_dhoni53.png',
#   './datasets/cropped/ms_dhoni\\ms_dhoni56.png',
#   './datasets/cropped/ms_dhoni\\ms_dhoni57.png',
#   './datasets/cropped/ms_dhoni\\ms_dhoni59.png',
#   './datasets/cropped/ms_dhoni\\ms_dhoni6.png',
#   './datasets/cropped/ms_dhoni\\ms_dhoni64.png',
#   './datasets/cropped/ms_dhoni\\ms_dhoni66.png',
#   './datasets/cropped/ms_dhoni\\ms_dhoni67.png',
#   './datasets/cropped/ms_dhoni\\ms_dhoni68.png',
#   './datasets/cropped/ms_dhoni\\ms_dhoni7.png',
#   './datasets/cropped/ms_dhoni\\ms_dhoni9.png'],
#  'smriti_mandhana': ['./datasets/cropped/smriti_mandhana\\smriti_mandhana1.png',
#   './datasets/cropped/smriti_mandhana\\smriti_mandhana10.png',
#   './datasets/cropped/smriti_mandhana\\smriti_mandhana11.png',
#   './datasets/cropped/smriti_mandhana\\smriti_mandhana12.png',
#   './datasets/cropped/smriti_mandhana\\smriti_mandhana13.png',
#   './datasets/cropped/smriti_mandhana\\smriti_mandhana14.png',
#   './datasets/cropped/smriti_mandhana\\smriti_mandhana15.png',
#   './datasets/cropped/smriti_mandhana\\smriti_mandhana16.png',
#   './datasets/cropped/smriti_mandhana\\smriti_mandhana17.png',
#   './datasets/cropped/smriti_mandhana\\smriti_mandhana18.png',
#   './datasets/cropped/smriti_mandhana\\smriti_mandhana19.png',
#   './datasets/cropped/smriti_mandhana\\smriti_mandhana2.png',
#   './datasets/cropped/smriti_mandhana\\smriti_mandhana20.png',
#   './datasets/cropped/smriti_mandhana\\smriti_mandhana21.png',
#   './datasets/cropped/smriti_mandhana\\smriti_mandhana22.png',
#   './datasets/cropped/smriti_mandhana\\smriti_mandhana23.png',
#   './datasets/cropped/smriti_mandhana\\smriti_mandhana24.png',
#   './datasets/cropped/smriti_mandhana\\smriti_mandhana25.png',
#   './datasets/cropped/smriti_mandhana\\smriti_mandhana26.png',
#   './datasets/cropped/smriti_mandhana\\smriti_mandhana27.png',
#   './datasets/cropped/smriti_mandhana\\smriti_mandhana28.png',
#   './datasets/cropped/smriti_mandhana\\smriti_mandhana3.png',
#   './datasets/cropped/smriti_mandhana\\smriti_mandhana30.png',
#   './datasets/cropped/smriti_mandhana\\smriti_mandhana31.png',
#   './datasets/cropped/smriti_mandhana\\smriti_mandhana33.png',
#   './datasets/cropped/smriti_mandhana\\smriti_mandhana34.png',
#   './datasets/cropped/smriti_mandhana\\smriti_mandhana35.png',
#   './datasets/cropped/smriti_mandhana\\smriti_mandhana36.png',
#   './datasets/cropped/smriti_mandhana\\smriti_mandhana37.png',
#   './datasets/cropped/smriti_mandhana\\smriti_mandhana38.png',
#   './datasets/cropped/smriti_mandhana\\smriti_mandhana39.png',
#   './datasets/cropped/smriti_mandhana\\smriti_mandhana4.png',
#   './datasets/cropped/smriti_mandhana\\smriti_mandhana40.png',
#   './datasets/cropped/smriti_mandhana\\smriti_mandhana41.png',
#   './datasets/cropped/smriti_mandhana\\smriti_mandhana42.png',
#   './datasets/cropped/smriti_mandhana\\smriti_mandhana43.png',
#   './datasets/cropped/smriti_mandhana\\smriti_mandhana45.png',
#   './datasets/cropped/smriti_mandhana\\smriti_mandhana47.png',
#   './datasets/cropped/smriti_mandhana\\smriti_mandhana5.png',
#   './datasets/cropped/smriti_mandhana\\smriti_mandhana6.png',
#   './datasets/cropped/smriti_mandhana\\smriti_mandhana7.png',
#   './datasets/cropped/smriti_mandhana\\smriti_mandhana8.png',
#   './datasets/cropped/smriti_mandhana\\smriti_mandhana9.png'],
#  'virat_kohli': ['./datasets/cropped/virat_kohli\\virat_kohli1.png',
#   './datasets/cropped/virat_kohli\\virat_kohli10.png',
#   './datasets/cropped/virat_kohli\\virat_kohli11.png',
#   './datasets/cropped/virat_kohli\\virat_kohli12.png',
#   './datasets/cropped/virat_kohli\\virat_kohli13.png',
#   './datasets/cropped/virat_kohli\\virat_kohli14.png',
#   './datasets/cropped/virat_kohli\\virat_kohli16.png',
#   './datasets/cropped/virat_kohli\\virat_kohli18.png',
#   './datasets/cropped/virat_kohli\\virat_kohli22.png',
#   './datasets/cropped/virat_kohli\\virat_kohli24.png',
#   './datasets/cropped/virat_kohli\\virat_kohli27.png',
#   './datasets/cropped/virat_kohli\\virat_kohli28.png',
#   './datasets/cropped/virat_kohli\\virat_kohli29.png',
#   './datasets/cropped/virat_kohli\\virat_kohli32.png',
#   './datasets/cropped/virat_kohli\\virat_kohli34.png',
#   './datasets/cropped/virat_kohli\\virat_kohli35.png',
#   './datasets/cropped/virat_kohli\\virat_kohli36.png',
#   './datasets/cropped/virat_kohli\\virat_kohli44.png',
#   './datasets/cropped/virat_kohli\\virat_kohli45.png',
#   './datasets/cropped/virat_kohli\\virat_kohli47.png',
#   './datasets/cropped/virat_kohli\\virat_kohli54.png',
#   './datasets/cropped/virat_kohli\\virat_kohli55.png',
#   './datasets/cropped/virat_kohli\\virat_kohli57.png',
#   './datasets/cropped/virat_kohli\\virat_kohli58.png',
#   './datasets/cropped/virat_kohli\\virat_kohli59.png',
#   './datasets/cropped/virat_kohli\\virat_kohli6.png',
#   './datasets/cropped/virat_kohli\\virat_kohli60.png',
#   './datasets/cropped/virat_kohli\\virat_kohli63.png',
#   './datasets/cropped/virat_kohli\\virat_kohli65.png',
#   './datasets/cropped/virat_kohli\\virat_kohli66.png',
#   './datasets/cropped/virat_kohli\\virat_kohli67.png',
#   './datasets/cropped/virat_kohli\\virat_kohli70.png',
#   './datasets/cropped/virat_kohli\\virat_kohli72.png',
#   './datasets/cropped/virat_kohli\\virat_kohli75.png',
#   './datasets/cropped/virat_kohli\\virat_kohli76.png',
#   './datasets/cropped/virat_kohli\\virat_kohli77.png',
#   './datasets/cropped/virat_kohli\\virat_kohli78.png',
#   './datasets/cropped/virat_kohli\\virat_kohli79.png',
#   './datasets/cropped/virat_kohli\\virat_kohli80.png',
#   './datasets/cropped/virat_kohli\\virat_kohli82.png',
#   './datasets/cropped/virat_kohli\\virat_kohli83.png',
#   './datasets/cropped/virat_kohli\\virat_kohli84.png',
#   './datasets/cropped/virat_kohli\\virat_kohli9.png']}

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count += 1
class_dict
# Out:
# {'ellyse_perry': 0,
#  'lionel_messi': 1,
#  'ms_dhoni': 2,
#  'smriti_mandhana': 3,
#  'virat_kohli': 4}

# %% [markdown]
# ## Split the dictionary into X and Y

# %%
X = []
y = []

for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        scaled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img, 'db1', 5)
        scaled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scaled_raw_img.reshape(32*32*3, 1), scaled_img_har.reshape(32*32, 1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
len(X)
# Out:
# 215

# %%
X = np.array(X).reshape(len(X), 4096).astype(float)
X.shape
# Out:
# (215, 4096)

# %%
X[0]
# Out:
# array([ 18.,   3.,  47., ...,  23.,  67., 247.])

# %% [markdown]
# ## Import support vector classifier from SVM

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %% [markdown]
# ## Make pipeline for better hyperparameter

# %%
pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel='linear', C=10))])
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svc', SVC(C=10, kernel='linear'))])

# %%
pipe.score(X_test, y_test)
# Out:
# 0.8333333333333334

# %%
y_pred = pipe.predict(X_test)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      1.00      0.87        10
#            1       1.00      0.80      0.89        10
#            2       0.73      0.80      0.76        10
#            3       0.88      0.88      0.88        16
#            4       0.83      0.62      0.71         8
#
#     accuracy                           0.83        54
#    macro avg       0.84      0.82      0.82        54
# weighted avg       0.85      0.83      0.83        54

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.8333333333333334

# %% [markdown]
# ## Check diffrent alogrithms if they give better accuracy then SVM

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf = GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores, columns=['model', 'best_score', 'best_params'])
df
# Out:
#                  model  best_score  \
# 0                  svm    0.850758
# 1        random_forest    0.576705
# 2  logistic_regression    0.838826
#
#                                     best_params
# 0        {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                  {'logisticregression__C': 1}

# %%
best_estimators
# Out:
# {'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc',
#                   SVC(C=1, gamma='auto', kernel='linear', probability=True))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=10))]),
#  'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=1, solver='liblinear'))])}

# %%
best_estimators['svm'].score(X_test, y_test)
# Out:
# 0.8333333333333334

# %%
best_estimators['random_forest'].score(X_test, y_test)
# Out:
# 0.6296296296296297

# %%
best_estimators['logistic_regression'].score(X_test, y_test)
# Out:
# 0.8888888888888888

# %%
best_clf = best_estimators['svm']

# %%
import seaborn as sns
plt.figure()
cm = confusion_matrix(y_test, best_clf.predict(X_test))
sns.heatmap(cm, annot=True)
plt.xlabel('Truth value')
plt.ylabel('predicted')
# Out:
# Text(33.0, 0.5, 'predicted')

# %%
class_dict
# Out:
# {'ellyse_perry': 0,
#  'lionel_messi': 1,
#  'ms_dhoni': 2,
#  'smriti_mandhana': 3,
#  'virat_kohli': 4}

# %%
import joblib
joblib.dump(best_clf, 'saved_model.pkl')
# Out:
# ['saved_model.pkl']
